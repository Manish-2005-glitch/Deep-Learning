# %%
from sklearn.datasets import make_classification
import numpy as np
import matplotlib.pyplot as plt

# %%
X, y = make_classification(n_samples=100, n_features=2, n_informative=1,n_redundant=0,
                           n_classes=2, n_clusters_per_class=1, random_state=41,hypercube=False,class_sep=10)

# %%
plt.figure(figsize=(10,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)

# %%
def perceptron(X, y, max_iter=1000, learning_rate=0.1):
    # Initialize weights and bias
    n_samples, n_features = X.shape
    weights = np.zeros(n_features)
    bias = 0
    
    # Training
    for _ in range(max_iter):
        for idx, x_i in enumerate(X):
            # Define step variable that was missing
            step = 1 if np.dot(x_i, weights) + bias > 0 else 0
            
            # Update weights and bias
            weights += learning_rate * (y[idx] - step) * x_i
            bias += learning_rate * (y[idx] - step)
    
    return bias, weights

intercept_, coef_ = perceptron(X, y)

# %%
intercept_,coef_ = perceptron(X,y)

# %%
print(coef_)
print(intercept_)
# Out:
# [0.27594296 0.01727671]
# 0.2

# %%
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input + b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
